# %% [markdown]
# <img src="./Imagenes/logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de los Circuitos II
#
# # Trabajo Práctico N1
# #### Alumno:    Lucas Gallero
# #### Profesor:  Mariano Llamedo Soria
# #### Ayudante de TPs:    David Moharos
# ----

# %% [markdown]
# # Enunciado:
#
# ## Filtro asignado: Filtro E
#
# En este trabajo práctico se realizará el diseño, análisis, simulación, implementación y medición de un filtro activo correspondiente al **Filtro E**.
#
# El filtro asignado utiliza una aproximación **Bessel**, cuya característica principal es presentar un **retardo de grupo aproximadamente constante** dentro de la banda de interés.
#
# ---
#
# ## Especificaciones del filtro
#
# | Parámetro | Valor |
# |---|---:|
# | Filtro asignado | E |
# | Función de aproximación | Bessel |
# | Retardo constante | 80 μs |
# | Desvío máximo del retardo | 5% a 3 kHz |
# | Atenuación máxima | 1 dB a 2 kHz |
#
# ---
#
# ## Objetivo
#
# El objetivo del trabajo es diseñar e implementar un filtro activo que cumpla con las especificaciones dadas para el **Filtro E**.
#
# Para ello se deberá obtener la función transferencia del filtro, analizar su respuesta en frecuencia, simular su comportamiento y comparar los resultados teóricos con los obtenidos mediante simulación circuital y mediciones de laboratorio.
#
# ---
#
# ## Desarrollo del trabajo
#
# El trabajo se dividirá en las siguientes etapas:
#
# 1. Análisis teórico del filtro.
# 2. Obtención de la función transferencia.
# 3. Simulación numérica en Python.
# 4. Simulación circuital.
# 5. Implementación práctica del circuito.
# 6. Medición en laboratorio.
# 7. Comparación entre resultados teóricos, simulados y medidos.
#
# ---
#
# ## Análisis teórico
#
# A partir de las especificaciones del filtro, se deberá determinar el orden necesario para cumplir con las condiciones de diseño.
#
# Luego se obtendrá la función transferencia en el dominio de Laplace:
#
# \[
# H(s)
# \]
#
# A partir de dicha función se analizarán:
#
# - Polos del sistema.
# - Ceros del sistema, si correspondiera.
# - Respuesta en módulo.
# - Respuesta en fase.
# - Retardo de grupo.
#
# El análisis deberá verificar que el filtro presente un retardo de grupo cercano a **80 μs** y que el desvío del retardo no supere el **5% a 3 kHz**.
#
# ---
#
# ## Simulación numérica
#
# Se realizará una simulación numérica en Python de la función transferencia obtenida.
#
# Mediante esta simulación se deberán obtener las siguientes gráficas:
#
# - Módulo en función de la frecuencia.
# - Fase en función de la frecuencia.
# - Retardo de grupo en función de la frecuencia.
#
# Estas gráficas permitirán comprobar el comportamiento ideal del filtro y verificar el cumplimiento de las especificaciones.
#
# ---
#
# ## Simulación circuital
#
# Se realizará la simulación del circuito implementado utilizando un simulador tipo SPICE.
#
# En esta etapa se deberá comprobar que el circuito propuesto reproduzca correctamente la función transferencia obtenida en el análisis teórico.
#
# Se deberán obtener nuevamente las gráficas de:
#
# - Módulo.
# - Fase.
# - Retardo de grupo.
#
# Luego se compararán los resultados de la simulación circuital con los obtenidos mediante Python.
#
# ---
#
# ## Implementación práctica
#
# El circuito será implementado utilizando componentes activos y pasivos disponibles en el laboratorio.
#
# Durante el armado se deberán tener en cuenta las siguientes recomendaciones:
#
# - Utilizar una alimentación adecuada para los amplificadores operacionales.
# - Incorporar capacitores de desacople en la alimentación.
# - Utilizar puntos de prueba para medir entrada y salida.
# - Verificar la correcta conexión de todos los componentes.
# - Evitar cables largos o conexiones que puedan introducir ruido.
# - Incluir elementos de ajuste si fuera necesario corregir pequeñas desviaciones debidas a tolerancias.
#
# ---
#
# ## Mediciones de laboratorio
#
# Una vez armado el circuito, se realizarán mediciones experimentales utilizando:
#
# - Generador de funciones.
# - Osciloscopio.
# - Fuente de alimentación.
# - Multímetro.
#
# Se aplicará una señal senoidal de entrada y se medirá la señal de salida para distintas frecuencias.
#
# A partir de estas mediciones se obtendrán experimentalmente:
#
# - Ganancia en función de la frecuencia.
# - Diferencia de fase entre entrada y salida.
# - Retardo de grupo.
#
# ---

# %%
# PyTC2: La librería para TC2
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

from scipy.signal import TransferFunction
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import sympy as sp
from sympy.abc import s
from IPython.display import display, Math
from scipy import signal
# las librerías que usarremos las cargamos solo una vez.

# %% [markdown]
# ---
#
# # Resolucíon:
